# %% [markdown]
# # Proyecto: Predicción de Alzheimer a partir de MRI usando Deep Learning

# %% [markdown]
# ## **0. Integrantes del equipo de trabajo**
# ---
# 1. RAÚL RAMÍREZ PENAGOS
# 2. IVÁN QUEVEDO
# 3. LINA ÁVILA MORENO

# %% [markdown]
# ## **1. Carga de los datos**

# %% [markdown]
# El proyecto utilizará un dataset público de imágenes de resonancia magnética del cerebro, este se encuentra estructurado en cuatro clases asociadas al
# nivel de progresión de la enfermedad (Non-Demented, Very Mild Demented, Mild Demented y Moderate Demented). Este dataset fue obtenido desde Kaggle (https://www.kaggle.com/datasets/borhanitrash/alzheimer-mri-disease-classification-dataset/data) y se encuentra almacenado en archivos parquet los cuales contienen
# 6400 imágenes codificadas.

# %%
import os

# %%
# !pip install kagglehub
import kagglehub

# %%
path = kagglehub.dataset_download("borhanitrash/alzheimer-mri-disease-classification-dataset")
# Out:
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 26.0M/26.0M [00:01<00:00, 17.5MB/s]
# Extracting files...

# %%
os.listdir(path+"/Alzheimer MRI Disease Classification Dataset/Data")
# Out:
# ['train-00000-of-00001-c08a401c53fe5312.parquet',
#  'test-00000-of-00001-44110b9df98c5585.parquet']

# %%
from minio import Minio
import pandas as pd
from io import BytesIO

client = Minio(
    endpoint="localhost:9000",
    access_key="admin",
    secret_key="password123",
    secure=False
)

bucket_name = "mlds3"

if not client.bucket_exists(bucket_name=bucket_name):
    client.make_bucket(bucket_name=bucket_name)


data = client.get_object(bucket_name=bucket_name, object_name="train.parquet")
df_train = pd.read_parquet(BytesIO(data.read()))

data = client.get_object(bucket_name=bucket_name, object_name="test.parquet")
df_test = pd.read_parquet(BytesIO(data.read()))

# %%
df_train
# Out:
#                                                   image  label
# 0     {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...      2
# 1     {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...      0
# 2     {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...      3
# 3     {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...      3
# 4     {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...      2
# ...                                                 ...    ...
# 5115  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...      3
# 5116  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...      3
# 5117  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...      3
# 5118  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...      0
# 5119  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...      2
#
# [5120 rows x 2 columns]

# %%
df_test
# Out:
#                                                   image  label
# 0     {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...      3
# 1     {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...      0
# 2     {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...      2
# 3     {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...      3
# 4     {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...      0
# ...                                                 ...    ...
# 1275  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...      3
# 1276  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...      2
# 1277  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...      3
# 1278  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...      2
# 1279  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...      3
#
# [1280 rows x 2 columns]
